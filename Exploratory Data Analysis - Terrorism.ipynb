# %% [markdown]
# ![Sparks.png](attachment:Sparks.png)

# %% [markdown]
# ## _The Sparks Foundation Internship_
#
# ### _Task 1 - Exploratory Data Analysis (EDA) - Terrorism_
#
# _Code Auther - Manoj Kumar_
#
# _Graduate Rotational Internship Program_

# %% [markdown]
# ## _Import the required modules_

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## _Read the dataset_

# %%
data=pd.read_csv('E:\Mano@workspace\Datasets\globalterrorismdb_0718dist.csv',encoding ='latin =1')

# %%
data.head(10)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
# 5  197001010002   1970       1     1        NaN         0        NaN      217
# 6  197001020001   1970       1     2        NaN         0        NaN      218
# 7  197001020002   1970       1     2        NaN         0        NaN      217
# 8  197001020003   1970       1     2        NaN         0        NaN      217
# 9  197001030001   1970       1     3        NaN         0        NaN      217
#
#           country_txt  region  ...  \
# 0  Dominican Republic       2  ...
# 1              Mexico       1  ...
# ...

# %%
data.shape
# Out:
# (181691, 135)

# %% [markdown]
# ## _Data Transformation_

# %%
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
data=data.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','region_txt':'Region',
                             'provstate':'State','city':'City','attacktype1_txt':'Attack_type','targtype1_txt':'Target_type',
                             'targsubtype1_txt':'Target_subtype','gname':'Gang_name','weaptype1_txt':'Weapon_type'})

# %%
data.head(5)
# Out:
#         eventid  Year  Month  Day approxdate  extended resolution  country  \
# 0  197000000001  1970      7    2        NaN         0        NaN       58
# 1  197000000002  1970      0    0        NaN         0        NaN      130
# 2  197001000001  1970      1    0        NaN         0        NaN      160
# 3  197001000002  1970      1    0        NaN         0        NaN       78
# 4  197001000003  1970      1    0        NaN         0        NaN      101
#
#               Country  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# ...

# %%
data=data[['Year','Month','Day','Country','Region','State','City','Attack_type','Target_type','Target_subtype','Gang_name','Weapon_type']]

# %%
data
# Out:
#         Year  Month  Day             Country                       Region  \
# 0       1970      7    2  Dominican Republic  Central America & Caribbean
# 1       1970      0    0              Mexico                North America
# 2       1970      1    0         Philippines               Southeast Asia
# 3       1970      1    0              Greece               Western Europe
# 4       1970      1    0               Japan                    East Asia
# ...      ...    ...  ...                 ...                          ...
# 181686  2017     12   31             Somalia           Sub-Saharan Africa
# 181687  2017     12   31               Syria   Middle East & North Africa
# 181688  2017     12   31         Philippines               Southeast Asia
# 181689  2017     12   31               India                   South Asia
# 181690  2017     12   31         Philippines               Southeast Asia
#
#                   State           City                     Attack_type  \
# ...

# %%
data['Target_subtype'] = data['Target_subtype'].fillna('others')
data['State']=data['State'].fillna('Unknown')
data['City']=data['City'].fillna('Unknown')
data.replace( {"Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)": "Vehicle"},inplace = True)

# %%
data.head()
# Out:
#    Year  Month  Day             Country                       Region    State  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean  Unknown
# 1  1970      0    0              Mexico                North America  Federal
# 2  1970      1    0         Philippines               Southeast Asia   Tarlac
# 3  1970      1    0              Greece               Western Europe   Attica
# 4  1970      1    0               Japan                    East Asia  Fukouka
#
#             City                     Attack_type                  Target_type  \
# 0  Santo Domingo                   Assassination  Private Citizens & Property
# 1    Mexico city     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2        Unknown                   Assassination          Journalists & Media
# 3         Athens               Bombing/Explosion      Government (Diplomatic)
# 4        Fukouka  Facility/Infrastructure Attack      Government (Diplomatic)
#
# ...

# %%
data.shape
# Out:
# (181691, 12)

# %%
data.isnull()
# Out:
#          Year  Month    Day  Country  Region  State   City  Attack_type  \
# 0       False  False  False    False   False  False  False        False
# 1       False  False  False    False   False  False  False        False
# 2       False  False  False    False   False  False  False        False
# 3       False  False  False    False   False  False  False        False
# 4       False  False  False    False   False  False  False        False
# ...       ...    ...    ...      ...     ...    ...    ...          ...
# 181686  False  False  False    False   False  False  False        False
# 181687  False  False  False    False   False  False  False        False
# 181688  False  False  False    False   False  False  False        False
# 181689  False  False  False    False   False  False  False        False
# 181690  False  False  False    False   False  False  False        False
#
#         Target_type  Target_subtype  Gang_name  Weapon_type
# ...

# %%
data.isnull().sum()
# Out:
# Year              0
# Month             0
# Day               0
# Country           0
# Region            0
# State             0
# City              0
# Attack_type       0
# Target_type       0
# Target_subtype    0
# Gang_name         0
# Weapon_type       0
# dtype: int64

# %% [markdown]
# ## _Data Analysing_

# %%
data.columns.unique()
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'Region', 'State', 'City',
#        'Attack_type', 'Target_type', 'Target_subtype', 'Gang_name',
#        'Weapon_type'],
#       dtype='object')

# %%
data.columns.nunique()
# Out:
# 12

# %%
Total_countries=data['Country'].nunique()
print("Total Countries were noted in the data:",Total_countries)
# Out:
# Total Countries were noted in the data: 205

# %%
print("The Noted regions are:\n",data['Region'].unique())
# Out:
# The Noted regions are:
#  ['Central America & Caribbean' 'North America' 'Southeast Asia'
#  'Western Europe' 'East Asia' 'South America' 'Eastern Europe'
#  'Sub-Saharan Africa' 'Middle East & North Africa' 'Australasia & Oceania'
#  'South Asia' 'Central Asia']

# %%
print("------------ Attack Type -----------\n",data['Attack_type'].unique())
print("\n---------- Target Type ----------\n",data['Target_type'].unique())
print("\n---------- Gang Name ---------\n",data['Gang_name'].unique())
print("\n---------- Number of Gangs --------\n",data['Gang_name'].nunique())
print("\n----------- Weapon Type ----------\n",data['Weapon_type'].unique())
# Out:
# ------------ Attack Type -----------
#  ['Assassination' 'Hostage Taking (Kidnapping)' 'Bombing/Explosion'
#  'Facility/Infrastructure Attack' 'Armed Assault' 'Hijacking' 'Unknown'
#  'Unarmed Assault' 'Hostage Taking (Barricade Incident)']
#
# ---------- Target Type ----------
#  ['Private Citizens & Property' 'Government (Diplomatic)'
#  'Journalists & Media' 'Police' 'Utilities' 'Military'
#  'Government (General)' 'Airports & Aircraft' 'Business'
#  'Educational Institution' 'Violent Political Party'
#  'Religious Figures/Institutions' 'Unknown' 'Transportation' 'Tourists'
#  'NGO' 'Telecommunication' 'Food or Water Supply'
#  'Terrorists/Non-State Militia' 'Other' 'Maritime' 'Abortion Related']
#
# ---------- Gang Name ---------
#  ['MANO-D' '23rd of September Communist League' 'Unknown' ...
#  'Fatoni Warriors' 'Minorities of Metropolitan Attacks'
#  'Baloch Republican Party']
#
# ---------- Number of Gangs --------
#  3537
#
# ----------- Weapon Type ----------
# ...

# %%
data.describe()
# Out:
#                 Year          Month            Day
# count  181691.000000  181691.000000  181691.000000
# mean     2002.638997       6.467277      15.505644
# std        13.259430       3.388303       8.814045
# min      1970.000000       0.000000       0.000000
# 25%      1991.000000       4.000000       8.000000
# 50%      2009.000000       6.000000      15.000000
# 75%      2014.000000       9.000000      23.000000
# max      2017.000000      12.000000      31.000000

# %%
data['Country'].value_counts().head(10)
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: Country, dtype: int64

# %%
data['Region'].value_counts().head(10)
# Out:
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Name: Region, dtype: int64

# %%
data['State'].value_counts().head(10)
# Out:
# Baghdad               7645
# Unknown               4711
# Northern Ireland      4498
# Balochistan           3710
# Saladin               3411
# Al Anbar              3299
# Nineveh               3241
# Sindh                 3206
# Khyber Pakhtunkhwa    3084
# Diyala                3041
# Name: State, dtype: int64

# %%
data['Target_subtype'].value_counts().head(10)
# Out:
# Unnamed Civilian/Unspecified                               11596
# Police Security Forces/Officers                            11178
# others                                                     10373
# Military Unit/Patrol/Convoy                                 8277
# Military Personnel (soldiers, troops, officers, forces)     7963
# Government Personnel (excluding police, military)           6610
# Village/City/Town/Suburb                                    6542
# Politician or Political Party Movement/Meeting/Rally        6306
# Police Building (headquarters, station, school)             5907
# Military Barracks/Base/Headquarters/Checkpost               5211
# Name: Target_subtype, dtype: int64

# %%
data['City'].value_counts().head(10)
# Out:
# Unknown         10209
# Baghdad          7589
# Karachi          2652
# Lima             2359
# Mosul            2265
# Belfast          2171
# Santiago         1621
# Mogadishu        1581
# San Salvador     1558
# Istanbul         1048
# Name: City, dtype: int64

# %%
data['Attack_type'].value_counts().head(10)
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: Attack_type, dtype: int64

# %%
data['Target_type'].value_counts().head(10)
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Name: Target_type, dtype: int64

# %%
data['Gang_name'].value_counts().head(10)
# Out:
# Unknown                                             82782
# Taliban                                              7478
# Islamic State of Iraq and the Levant (ISIL)          5613
# Shining Path (SL)                                    4555
# Farabundo Marti National Liberation Front (FMLN)     3351
# Al-Shabaab                                           3288
# New People's Army (NPA)                              2772
# Irish Republican Army (IRA)                          2671
# Revolutionary Armed Forces of Colombia (FARC)        2487
# Boko Haram                                           2418
# Name: Gang_name, dtype: int64

# %%
data['Weapon_type'].value_counts().head(5)
# Out:
# Explosives    92426
# Firearms      58524
# Unknown       15157
# Incendiary    11135
# Melee          3655
# Name: Weapon_type, dtype: int64

# %% [markdown]
# ### _Visualizations_

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data.head()
# Out:
#    Year  Month  Day             Country                       Region    State  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean  Unknown
# 1  1970      0    0              Mexico                North America  Federal
# 2  1970      1    0         Philippines               Southeast Asia   Tarlac
# 3  1970      1    0              Greece               Western Europe   Attica
# 4  1970      1    0               Japan                    East Asia  Fukouka
#
#             City                     Attack_type                  Target_type  \
# 0  Santo Domingo                   Assassination  Private Citizens & Property
# 1    Mexico city     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2        Unknown                   Assassination          Journalists & Media
# 3         Athens               Bombing/Explosion      Government (Diplomatic)
# 4        Fukouka  Facility/Infrastructure Attack      Government (Diplomatic)
#
# ...

# %%
plt.figure(figsize=(20,5))
plt.title("WEAPON TYPES")
sns.countplot(x=data.Weapon_type)
# Out:
# <AxesSubplot: title={'center': 'WEAPON TYPES'}, xlabel='Weapon_type', ylabel='count'>

# %%
plt.figure(figsize=(20,5))
plt.title("ATTACKS BY YEAR")
plt.xticks(rotation=90)
sns.countplot(x=data.Year)
# Out:
# <AxesSubplot: title={'center': 'ATTACKS BY YEAR'}, xlabel='Year', ylabel='count'>

# %%
plt.figure(figsize=(20,5))
plt.title("ATTACKS BY MONTH")
sns.countplot(x=data.Month)
# Out:
# <AxesSubplot: title={'center': 'ATTACKS BY MONTH'}, xlabel='Month', ylabel='count'>

# %%
plt.figure(figsize=(20,5))
plt.title("ATTACK BY DAYS")
sns.countplot(x=data.Day)
# Out:
# <AxesSubplot: title={'center': 'ATTACK BY DAYS'}, xlabel='Day', ylabel='count'>

# %%
plt.figure(figsize=(25,8))
plt.title("ATTACK BY COUNTRY")
plt.rcParams.update({'font.size':8})
plt.xticks(rotation=90)
sns.countplot(x=data.Country)
# Out:
# <AxesSubplot: title={'center': 'ATTACK BY COUNTRY'}, xlabel='Country', ylabel='count'>

# %%
plt.figure(figsize=(20,5))
plt.title("ATTACK BY REGION")
plt.xticks(rotation=90)
sns.countplot(x=data.Region)
# Out:
# <AxesSubplot: title={'center': 'ATTACK BY REGION'}, xlabel='Region', ylabel='count'>

# %%
plt.figure(figsize=(20,5))
plt.title("ATTACKING TYPE")
plt.xticks(rotation=90)
sns.countplot(x=data.Attack_type)
# Out:
# <AxesSubplot: title={'center': 'ATTACKING TYPE'}, xlabel='Attack_type', ylabel='count'>

# %%
plt.figure(figsize=(20,5))
plt.title("TARGET TYPE")
plt.xticks(rotation=90)
sns.countplot(x=data.Target_type)
# Out:
# <AxesSubplot: title={'center': 'TARGET TYPE'}, xlabel='Target_type', ylabel='count'>

# %% [markdown]
# ### _Summary of Analysis_
#
# _~Attacks were more during 2014 and then in 2015_
#
# _~When compared to attacks from 1970 onwards, the last 6 years scored a maximum_
#
# _~But from 2014 onwards count started decreasing._
#
# _~Almost Every day has the same contribution but attacks were low during 31st and high during 15th and 1st._
#
# _~Iraq dominates all the countries and it has the highest number of attacks and then Pakistan, Afghanistan, and India follow it._
